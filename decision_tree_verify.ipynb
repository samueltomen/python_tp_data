# %%
import pandas as pd

data = pd.read_csv('fontaines-a-boire.csv', sep=';')

data.head(50)

# Nombbre de type de fontaines
data['type'].unique()
# Out:
#     Identifiant       Type Objet                               Modèle  \
# 0     450024929   BORNE_FONTAINE                            BF Bayard
# 1     450080523   BORNE_FONTAINE                   GHM Ville de Paris
# 2     450084801   BORNE_FONTAINE                   GHM Ville de Paris
# 3     450085138    FONTAINE_2EN1          Fontaine Totem 2en1 Atelier
# 4     450085141    FONTAINE_2EN1          Fontaine Totem 2en1 Atelier
# 5     450085303    FONTAINE_2EN1                           Mât source
# 6     450085262    FONTAINE_2EN1                           Mât source
# 7     450085265    FONTAINE_2EN1                           Mât source
# 8     450085036    FONTAINE_2EN1                           Mât source
# 9     450085037    FONTAINE_2EN1                           Mât source
# 10    450085039    FONTAINE_2EN1                           Mât source
# 11    450085123    FONTAINE_2EN1          Fontaine Totem 2en1 Atelier
# ...

# %%
# Nombbre de type de fontaines
data['Type Objet'].unique()
# Out:
# array(['BORNE_FONTAINE', 'FONTAINE_2EN1', 'FONTAINE_ARCEAU',
#        'FONTAINE_BOIS', 'FONTNE_WALLACE', 'FTNE_PETILLANTE',
#        'FONTAINE_TOTEM', 'FTNE_MILLENAIRE', 'FTNE_POING_EAU',
#        'FONTAINE_ALBIEN'], dtype=object)
